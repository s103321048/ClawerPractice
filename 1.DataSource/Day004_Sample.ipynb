# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"13710755965","type":"PushEvent","actor":{"id":36865688,"login":"ADCAdams","display_login":"ADCAdams","gravatar_id":"","url":"https://api.github.com/users/ADCAdams","avatar_url":"https://avatars.githubusercontent.com/u/36865688?"},"repo":{"id":300470921,"name":"ADCAdams/activerecord-crud-onl01-seng-pt-070620","url":"https://api.github.com/repos/ADCAdams/activerecord-crud-onl01-seng-pt-070620"},"payload":{"push_id":5785686325,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"7b253d49c95d252d00b4d397fd079357405d678f","before":"8cbee5958a4ed4b03f75f9fdd38918d0bc7931df","commits":[{"sha":"7b253d49c95d252d00b4d397fd079357405d678f","author":{"email":"andrewdcadams@gmail.com","name":"Andy Adams"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/ADCAdams/activerecord-crud-onl01-seng-pt-070620/commits/7b253d49c95d252d00b4d397fd079357405d678f"}]},"public":true,"created_at":"2020-10-02T02:08:10Z"},{"id":"13710755962","type":"PushEvent","actor":{"id":55732627,"login":"AliSulieman","display_login":"AliSulieman","gravatar_id":"","url":"https://api.github.com/users/AliSulieman","avatar_url":"https://avatars.githubusercontent.com/u/55732627?"},"repo":{"id":299778903,"name":"AliSulieman/try_django","url":"https://api.github.com/repos/AliSulieman/try_django"},"payload":{"push_id":5785686322,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a2959cfae053298edcd70b6869d2ce9af19dee97","before":"36fa2ff3c91745166c38aa4e253e724ab4541618","commits":[{"sha":"a2959cfae053298edcd70b6869d2ce9af19dee97","author":{"email":"ahsuliem@uno.edu","name":"Ali Sulieman"},"message":" learning how to work with html and rendering using django","distinct":true,"url":"https://api.github.com/repos/AliSulieman/try_django/commits/a2959cfae053298edcd70b6869d2ce9af19dee97"}]},"public":true,"created_at":"2020-10-02T02:08:10Z"},{"id":"13710755955","type":"PushEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":295991523,"name":"moniqueaz/won-games-client","url":"https://api.github.com/repos/moniqueaz/won-games-client"},"payload":{"push_id":5785686317,"size":7,"distinct_size":1,"ref":"refs/heads/dependabot/npm_and_yarn/types/jest-26.0.14","head":"68b04816b9e870be519fbcc04e344d622c7f05a3","before":"ac9790c90dedd2c24270038c33bc6e0653ff7c56","commits":[{"sha":"4d0cf485e819223ffae1ef9c32586c9d8d3b6103","author":{"email":"monique.azevedo@BRRJOBITAIM2724.local","name":"Monique Azevedo da Silva"},"message":"Altere versão eslint/parser de 4.1.1 para 4.0.1","distinct":false,"url":"https://api.github.com/repos/moniqueaz/won-games-client/commits/4d0cf485e819223ffae1ef9c32586c9d8d3b6103"},{"sha":"e3b927029c849c578724f164f9505f29f6242e41","author":{"email":"monique.azevedo@BRRJOBITAIM2724.local","name":"Monique Azevedo da Silva"},"message":"Ajuste thema e estulos do projeto","distinct":false,"url":"https://api.github.com/repos/moniqueaz/won-games-client/commits/e3b927029c849c578724f164f9505f29f6242e41"},{"sha":"a3415bf4dc031b2b6c13ff7c4ba7964a90b56a8e","author":{"email":"monique.azevedo@BRRJOBITAIM2724.local","name":"Monique Azevedo da Silva"},"message":"Adiciona theme no global","distinct":false,"url":"https://api.github.com/repos/moniqueaz/won-games-client/commits/a3415bf4dc031b2b6c13ff7c4ba7964a90b56a8e"},{"sha":"df715c474fff70f5ca152edf748505d10c798c2f","author":{"email":"monique.azevedo@BRRJOBITAIM2724.local","name":"Monique Azevedo da Silva"},"message":"Corrige global e ajusta modo de import do storybook","distinct":false,"url":"https://api.github.com/repos/moniqueaz/won-games-client/commits/df715c474fff70f5ca152edf748505d10c798c2f"},{"sha":"cffef5d13a7037a2451e467db57597bb57982702","author":{"email":"monique.azevedo@BRRJOBITAIM2724.local","name":"Monique Azevedo da Silva"},"message":"update project","distinct":false,"url":"https:// ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '13710755965',
#   'type': 'PushEvent',
#   'actor': {'id': 36865688,
#    'login': 'ADCAdams',
#    'display_login': 'ADCAdams',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ADCAdams',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36865688?'},
#   'repo': {'id': 300470921,
#    'name': 'ADCAdams/activerecord-crud-onl01-seng-pt-070620',
#    'url': 'https://api.github.com/repos/ADCAdams/activerecord-crud-onl01-seng-pt-070620'},
#   'payload': {'push_id': 5785686325,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '7b253d49c95d252d00b4d397fd079357405d678f',
#    'before': '8cbee5958a4ed4b03f75f9fdd38918d0bc7931df',
#    'commits': [{'sha': '7b253d49c95d252d00b4d397fd079357405d678f',
#      'author': {'email': 'andrewdcadams@gmail.com', 'name': 'Andy Adams'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ADCAdams/activerecord-crud-onl01-seng-pt-070620/commits/7b253d49c95d252d00b4d397fd079357405d678f'}]},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755962',
#   'type': 'PushEvent',
#   'actor': {'id': 55732627,
#    'login': 'AliSulieman',
#    'display_login': 'AliSulieman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AliSulieman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55732627?'},
#   'repo': {'id': 299778903,
#    'name': 'AliSulieman/try_django',
#    'url': 'https://api.github.com/repos/AliSulieman/try_django'},
#   'payload': {'push_id': 5785686322,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a2959cfae053298edcd70b6869d2ce9af19dee97',
#    'before': '36fa2ff3c91745166c38aa4e253e724ab4541618',
#    'commits': [{'sha': 'a2959cfae053298edcd70b6869d2ce9af19dee97',
#      'author': {'email': 'ahsuliem@uno.edu', 'name': 'Ali Sulieman'},
#      'message': ' learning how to work with html and rendering using django',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AliSulieman/try_django/commits/a2959cfae053298edcd70b6869d2ce9af19dee97'}]},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755955',
#   'type': 'PushEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 295991523,
#    'name': 'moniqueaz/won-games-client',
#    'url': 'https://api.github.com/repos/moniqueaz/won-games-client'},
#   'payload': {'push_id': 5785686317,
#    'size': 7,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dependabot/npm_and_yarn/types/jest-26.0.14',
#    'head': '68b04816b9e870be519fbcc04e344d622c7f05a3',
#    'before': 'ac9790c90dedd2c24270038c33bc6e0653ff7c56',
#    'commits': [{'sha': '4d0cf485e819223ffae1ef9c32586c9d8d3b6103',
#      'author': {'email': 'monique.azevedo@BRRJOBITAIM2724.local',
#       'name': 'Monique Azevedo da Silva'},
#      'message': 'Altere versão eslint/parser de 4.1.1 para 4.0.1',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moniqueaz/won-games-client/commits/4d0cf485e819223ffae1ef9c32586c9d8d3b6103'},
#     {'sha': 'e3b927029c849c578724f164f9505f29f6242e41',
#      'author': {'email': 'monique.azevedo@BRRJOBITAIM2724.local',
#       'name': 'Monique Azevedo da Silva'},
#      'message': 'Ajuste thema e estulos do projeto',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moniqueaz/won-games-client/commits/e3b927029c849c578724f164f9505f29f6242e41'},
#     {'sha': 'a3415bf4dc031b2b6c13ff7c4ba7964a90b56a8e',
#      'author': {'email': 'monique.azevedo@BRRJOBITAIM2724.local',
#       'name': 'Monique Azevedo da Silva'},
#      'message': 'Adiciona theme no global',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moniqueaz/won-games-client/commits/a3415bf4dc031b2b6c13ff7c4ba7964a90b56a8e'},
#     {'sha': 'df715c474fff70f5ca152edf748505d10c798c2f',
#      'author': {'email': 'monique.azevedo@BRRJOBITAIM2724.local',
#       'name': 'Monique Azevedo da Silva'},
#      'message': 'Corrige global e ajusta modo de import do storybook',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moniqueaz/won-games-client/commits/df715c474fff70f5ca152edf748505d10c798c2f'},
#     {'sha': 'cffef5d13a7037a2451e467db57597bb57982702',
#      'author': {'email': 'monique.azevedo@BRRJOBITAIM2724.local',
#       'name': 'Monique Azevedo da Silva'},
#      'message': 'update project',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moniqueaz/won-games-client/commits/cffef5d13a7037a2451e467db57597bb57982702'},
#     {'sha': '4d8cf26128c917028e8c601b2ba2924efbfea904',
#      'author': {'email': 'monique.azevedo@BRRJOBITAIM2724.local',
#       'name': 'Monique Azevedo da Silva'},
#      'message': 'Finaliza component logo',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/moniqueaz/won-games-client/commits/4d8cf26128c917028e8c601b2ba2924efbfea904'},
#     {'sha': '68b04816b9e870be519fbcc04e344d622c7f05a3',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump @types/jest from 26.0.13 to 26.0.14\n\nBumps [@types/jest](https://github.com/DefinitelyTyped/DefinitelyTyped/tree/HEAD/types/jest) from 26.0.13 to 26.0.14.\n- [Release notes](https://github.com/DefinitelyTyped/DefinitelyTyped/releases)\n- [Commits](https://github.com/DefinitelyTyped/DefinitelyTyped/commits/HEAD/types/jest)\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/moniqueaz/won-games-client/commits/68b04816b9e870be519fbcc04e344d622c7f05a3'}]},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755954',
#   'type': 'PushEvent',
#   'actor': {'id': 12563321,
#    'login': 'saabarbosa',
#    'display_login': 'saabarbosa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saabarbosa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12563321?'},
#   'repo': {'id': 298718096,
#    'name': 'saabarbosa/teste-aula01',
#    'url': 'https://api.github.com/repos/saabarbosa/teste-aula01'},
#   'payload': {'push_id': 5785686316,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '796ae2a899dcb705048dc652d80a23fe85d35cf5',
#    'before': 'c621a5ea883347baed8292c6ec540e5f8b3e8f4f',
#    'commits': [{'sha': '796ae2a899dcb705048dc652d80a23fe85d35cf5',
#      'author': {'email': 'saabarbosa@gmail.com',
#       'name': 'SERGIO ANTONIO A BARBOSA'},
#      'message': 'meu commit number x',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/saabarbosa/teste-aula01/commits/796ae2a899dcb705048dc652d80a23fe85d35cf5'}]},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755956',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 191633992,
#    'name': 's4heid/branch-switcher',
#    'url': 'https://api.github.com/repos/s4heid/branch-switcher'},
#   'payload': {'action': 'opened',
#    'number': 122,
#    'pull_request': {'url': 'https://api.github.com/repos/s4heid/branch-switcher/pulls/122',
#     'id': 496639409,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDk2NjM5NDA5',
#     'html_url': 'https://github.com/s4heid/branch-switcher/pull/122',
#     'diff_url': 'https://github.com/s4heid/branch-switcher/pull/122.diff',
#     'patch_url': 'https://github.com/s4heid/branch-switcher/pull/122.patch',
#     'issue_url': 'https://api.github.com/repos/s4heid/branch-switcher/issues/122',
#     'number': 122,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump @types/jest from 25.1.4 to 26.0.14',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@types/jest](https://github.com/DefinitelyTyped/DefinitelyTyped/tree/HEAD/types/jest) from 25.1.4 to 26.0.14.\n<details>\n<summary>Commits</summary>\n<ul>\n<li>See full diff in <a href="https://github.com/DefinitelyTyped/DefinitelyTyped/commits/HEAD/types/jest">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=@types/jest&package-manager=npm_and_yarn&previous-version=25.1.4&new-version=26.0.14)](https://dependabot.com/compatibility-score/?dependency-name=@types/jest&package-manager=npm_and_yarn&previous-version=25.1.4&new-version=26.0.14)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n- `@dependabot badge me` will comment on this PR with code to add a "Dependabot enabled" badge to your readme\n\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\n- Update frequency (including time of day and day of week)\n- Pull request limits (per update run and/or open at any time)\n- Out-of-range updates (receive only lockfile updates, if desired)\n- Security updates (receive only security updates, if desired)\n\n\n\n</details>',
#     'created_at': '2020-10-02T02:08:10Z',
#     'updated_at': '2020-10-02T02:08:10Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/s4heid/branch-switcher/pulls/122/commits',
#     'review_comments_url': 'https://api.github.com/repos/s4heid/branch-switcher/pulls/122/comments',
#     'review_comment_url': 'https://api.github.com/repos/s4heid/branch-switcher/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/s4heid/branch-switcher/issues/122/comments',
#     'statuses_url': 'https://api.github.com/repos/s4heid/branch-switcher/statuses/8fb414cc12c19d2e94ff94bb5748b37640b72587',
#     'head': {'label': 's4heid:dependabot/npm_and_yarn/types/jest-26.0.14',
#      'ref': 'dependabot/npm_and_yarn/types/jest-26.0.14',
#      'sha': '8fb414cc12c19d2e94ff94bb5748b37640b72587',
#      'user': {'login': 's4heid',
#       'id': 8442432,
#       'node_id': 'MDQ6VXNlcjg0NDI0MzI=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/8442432?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/s4heid',
#       'html_url': 'https://github.com/s4heid',
#       'followers_url': 'https://api.github.com/users/s4heid/followers',
#       'following_url': 'https://api.github.com/users/s4heid/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/s4heid/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/s4heid/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/s4heid/subscriptions',
#       'organizations_url': 'https://api.github.com/users/s4heid/orgs',
#       'repos_url': 'https://api.github.com/users/s4heid/repos',
#       'events_url': 'https://api.github.com/users/s4heid/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/s4heid/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 191633992,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTE2MzM5OTI=',
#       'name': 'branch-switcher',
#       'full_name': 's4heid/branch-switcher',
#       'private': False,
#       'owner': {'login': 's4heid',
#        'id': 8442432,
#        'node_id': 'MDQ6VXNlcjg0NDI0MzI=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/8442432?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/s4heid',
#        'html_url': 'https://github.com/s4heid',
#        'followers_url': 'https://api.github.com/users/s4heid/followers',
#        'following_url': 'https://api.github.com/users/s4heid/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/s4heid/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/s4heid/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/s4heid/subscriptions',
#        'organizations_url': 'https://api.github.com/users/s4heid/orgs',
#        'repos_url': 'https://api.github.com/users/s4heid/repos',
#        'events_url': 'https://api.github.com/users/s4heid/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/s4heid/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/s4heid/branch-switcher',
#       'description': 'a GitHub bot that switches the base branch of pull requests to the preferred branch',
#       'fork': False,
#       'url': 'https://api.github.com/repos/s4heid/branch-switcher',
#       'forks_url': 'https://api.github.com/repos/s4heid/branch-switcher/forks',
#       'keys_url': 'https://api.github.com/repos/s4heid/branch-switcher/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/s4heid/branch-switcher/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/s4heid/branch-switcher/teams',
#       'hooks_url': 'https://api.github.com/repos/s4heid/branch-switcher/hooks',
#       'issue_events_url': 'https://api.github.com/repos/s4heid/branch-switcher/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/s4heid/branch-switcher/events',
#       'assignees_url': 'https://api.github.com/repos/s4heid/branch-switcher/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/s4heid/branch-switcher/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/s4heid/branch-switcher/tags',
#       'blobs_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/s4heid/branch-switcher/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/s4heid/branch-switcher/languages',
#       'stargazers_url': 'https://api.github.com/repos/s4heid/branch-switcher/stargazers',
#       'contributors_url': 'https://api.github.com/repos/s4heid/branch-switcher/contributors',
#       'subscribers_url': 'https://api.github.com/repos/s4heid/branch-switcher/subscribers',
#       'subscription_url': 'https://api.github.com/repos/s4heid/branch-switcher/subscription',
#       'commits_url': 'https://api.github.com/repos/s4heid/branch-switcher/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/s4heid/branch-switcher/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/s4heid/branch-switcher/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/s4heid/branch-switcher/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/s4heid/branch-switcher/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/s4heid/branch-switcher/merges',
#       'archive_url': 'https://api.github.com/repos/s4heid/branch-switcher/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/s4heid/branch-switcher/downloads',
#       'issues_url': 'https://api.github.com/repos/s4heid/branch-switcher/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/s4heid/branch-switcher/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/s4heid/branch-switcher/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/s4heid/branch-switcher/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/s4heid/branch-switcher/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/s4heid/branch-switcher/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/s4heid/branch-switcher/deployments',
#       'created_at': '2019-06-12T19:41:38Z',
#       'updated_at': '2020-08-27T13:35:21Z',
#       'pushed_at': '2020-10-02T02:08:09Z',
#       'git_url': 'git://github.com/s4heid/branch-switcher.git',
#       'ssh_url': 'git@github.com:s4heid/branch-switcher.git',
#       'clone_url': 'https://github.com/s4heid/branch-switcher.git',
#       'svn_url': 'https://github.com/s4heid/branch-switcher',
#       'homepage': 'https://github.com/apps/branch-switcher',
#       'size': 1794,
#       'stargazers_count': 10,
#       'watchers_count': 10,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 9,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 9,
#       'watchers': 10,
#       'default_branch': 'master'}},
#     'base': {'label': 's4heid:master',
#      'ref': 'master',
#      'sha': '9cb596b9858ab812a3cb36eeb14f26af5c9b54a7',
#      'user': {'login': 's4heid',
#       'id': 8442432,
#       'node_id': 'MDQ6VXNlcjg0NDI0MzI=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/8442432?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/s4heid',
#       'html_url': 'https://github.com/s4heid',
#       'followers_url': 'https://api.github.com/users/s4heid/followers',
#       'following_url': 'https://api.github.com/users/s4heid/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/s4heid/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/s4heid/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/s4heid/subscriptions',
#       'organizations_url': 'https://api.github.com/users/s4heid/orgs',
#       'repos_url': 'https://api.github.com/users/s4heid/repos',
#       'events_url': 'https://api.github.com/users/s4heid/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/s4heid/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 191633992,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTE2MzM5OTI=',
#       'name': 'branch-switcher',
#       'full_name': 's4heid/branch-switcher',
#       'private': False,
#       'owner': {'login': 's4heid',
#        'id': 8442432,
#        'node_id': 'MDQ6VXNlcjg0NDI0MzI=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/8442432?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/s4heid',
#        'html_url': 'https://github.com/s4heid',
#        'followers_url': 'https://api.github.com/users/s4heid/followers',
#        'following_url': 'https://api.github.com/users/s4heid/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/s4heid/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/s4heid/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/s4heid/subscriptions',
#        'organizations_url': 'https://api.github.com/users/s4heid/orgs',
#        'repos_url': 'https://api.github.com/users/s4heid/repos',
#        'events_url': 'https://api.github.com/users/s4heid/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/s4heid/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/s4heid/branch-switcher',
#       'description': 'a GitHub bot that switches the base branch of pull requests to the preferred branch',
#       'fork': False,
#       'url': 'https://api.github.com/repos/s4heid/branch-switcher',
#       'forks_url': 'https://api.github.com/repos/s4heid/branch-switcher/forks',
#       'keys_url': 'https://api.github.com/repos/s4heid/branch-switcher/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/s4heid/branch-switcher/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/s4heid/branch-switcher/teams',
#       'hooks_url': 'https://api.github.com/repos/s4heid/branch-switcher/hooks',
#       'issue_events_url': 'https://api.github.com/repos/s4heid/branch-switcher/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/s4heid/branch-switcher/events',
#       'assignees_url': 'https://api.github.com/repos/s4heid/branch-switcher/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/s4heid/branch-switcher/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/s4heid/branch-switcher/tags',
#       'blobs_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/s4heid/branch-switcher/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/s4heid/branch-switcher/languages',
#       'stargazers_url': 'https://api.github.com/repos/s4heid/branch-switcher/stargazers',
#       'contributors_url': 'https://api.github.com/repos/s4heid/branch-switcher/contributors',
#       'subscribers_url': 'https://api.github.com/repos/s4heid/branch-switcher/subscribers',
#       'subscription_url': 'https://api.github.com/repos/s4heid/branch-switcher/subscription',
#       'commits_url': 'https://api.github.com/repos/s4heid/branch-switcher/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/s4heid/branch-switcher/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/s4heid/branch-switcher/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/s4heid/branch-switcher/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/s4heid/branch-switcher/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/s4heid/branch-switcher/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/s4heid/branch-switcher/merges',
#       'archive_url': 'https://api.github.com/repos/s4heid/branch-switcher/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/s4heid/branch-switcher/downloads',
#       'issues_url': 'https://api.github.com/repos/s4heid/branch-switcher/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/s4heid/branch-switcher/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/s4heid/branch-switcher/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/s4heid/branch-switcher/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/s4heid/branch-switcher/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/s4heid/branch-switcher/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/s4heid/branch-switcher/deployments',
#       'created_at': '2019-06-12T19:41:38Z',
#       'updated_at': '2020-08-27T13:35:21Z',
#       'pushed_at': '2020-10-02T02:08:09Z',
#       'git_url': 'git://github.com/s4heid/branch-switcher.git',
#       'ssh_url': 'git@github.com:s4heid/branch-switcher.git',
#       'clone_url': 'https://github.com/s4heid/branch-switcher.git',
#       'svn_url': 'https://github.com/s4heid/branch-switcher',
#       'homepage': 'https://github.com/apps/branch-switcher',
#       'size': 1794,
#       'stargazers_count': 10,
#       'watchers_count': 10,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 9,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 9,
#       'watchers': 10,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/s4heid/branch-switcher/pulls/122'},
#      'html': {'href': 'https://github.com/s4heid/branch-switcher/pull/122'},
#      'issue': {'href': 'https://api.github.com/repos/s4heid/branch-switcher/issues/122'},
#      'comments': {'href': 'https://api.github.com/repos/s4heid/branch-switcher/issues/122/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/s4heid/branch-switcher/pulls/122/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/s4heid/branch-switcher/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/s4heid/branch-switcher/pulls/122/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/s4heid/branch-switcher/statuses/8fb414cc12c19d2e94ff94bb5748b37640b72587'}},
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 31,
#     'deletions': 37,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755949',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 8740057,
#    'login': 'janlazo',
#    'display_login': 'janlazo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/janlazo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8740057?'},
#   'repo': {'id': 16408992,
#    'name': 'neovim/neovim',
#    'url': 'https://api.github.com/repos/neovim/neovim'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/neovim/neovim/issues/13025',
#     'repository_url': 'https://api.github.com/repos/neovim/neovim',
#     'labels_url': 'https://api.github.com/repos/neovim/neovim/issues/13025/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/neovim/neovim/issues/13025/comments',
#     'events_url': 'https://api.github.com/repos/neovim/neovim/issues/13025/events',
#     'html_url': 'https://github.com/neovim/neovim/pull/13025',
#     'id': 713293939,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDk2NjM3Mjc4',
#     'number': 13025,
#     'title': "vim-patch:8.2.1762: when a timer uses :stopinsert completion isn't stopped",
#     'user': {'login': 'Happy-Dude',
#      'id': 1098725,
#      'node_id': 'MDQ6VXNlcjEwOTg3MjU=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/1098725?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Happy-Dude',
#      'html_url': 'https://github.com/Happy-Dude',
#      'followers_url': 'https://api.github.com/users/Happy-Dude/followers',
#      'following_url': 'https://api.github.com/users/Happy-Dude/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Happy-Dude/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Happy-Dude/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Happy-Dude/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Happy-Dude/orgs',
#      'repos_url': 'https://api.github.com/users/Happy-Dude/repos',
#      'events_url': 'https://api.github.com/users/Happy-Dude/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Happy-Dude/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-10-02T01:58:51Z',
#     'updated_at': '2020-10-02T02:08:10Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/neovim/neovim/pulls/13025',
#      'html_url': 'https://github.com/neovim/neovim/pull/13025',
#      'diff_url': 'https://github.com/neovim/neovim/pull/13025.diff',
#      'patch_url': 'https://github.com/neovim/neovim/pull/13025.patch'},
#     'body': "> Problem:    When a timer uses :stopinsert Insert mode completion isn't\r\n>             stopped. (Stanley Chan)\r\n> Solution:   Call ins_compl_prep(ESC).\r\n> https://github.com/vim/vim/commit/d0e1b7103c14eb0d175c6b245b4b6ed93a204da9\r\n\r\nFirst vim-patch PR to the project! Fixes bug https://github.com/neovim/neovim/issues/12976 and obsoletes @tjdevries's PR https://github.com/neovim/neovim/pull/12977\r\n\r\nI am unsure what to do with the `src/testdir/dumps/Test_pum_stopped_by_timer.dump` file.\r\n\r\n**NOTE**: https://github.com/vim/vim/issues/7035 mention additional patches that I am unsure we need in neovim:\r\n\r\n* https://github.com/vim/vim/commit/ad9ec5e79916d206fd7677b77e36485c47ae534f\r\n* https://github.com/vim/vim/commit/4537bcc88956f86267c25edf8008e0dbde598652\r\n\r\nIf these are necessary, I will make the changes accordingly 👍\r\n\r\nPinging @janlazo , @erw7 for review.",
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/neovim/neovim/issues/comments/702488601',
#     'html_url': 'https://github.com/neovim/neovim/pull/13025#issuecomment-702488601',
#     'issue_url': 'https://api.github.com/repos/neovim/neovim/issues/13025',
#     'id': 702488601,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDcwMjQ4ODYwMQ==',
#     'user': {'login': 'janlazo',
#      'id': 8740057,
#      'node_id': 'MDQ6VXNlcjg3NDAwNTc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/8740057?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/janlazo',
#      'html_url': 'https://github.com/janlazo',
#      'followers_url': 'https://api.github.com/users/janlazo/followers',
#      'following_url': 'https://api.github.com/users/janlazo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/janlazo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/janlazo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/janlazo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/janlazo/orgs',
#      'repos_url': 'https://api.github.com/users/janlazo/repos',
#      'events_url': 'https://api.github.com/users/janlazo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/janlazo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-10-02T02:08:10Z',
#     'updated_at': '2020-10-02T02:08:10Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "https://github.com/neovim/neovim/pull/12977#issuecomment-702307735 suggests that patch 8.2.1781, 8.2.1783 are needed but patch 8.2.1783 needs a function from patch 8.1.0035 for the prompt buffers.\r\n\r\nIf you want to continue porting this patch, then you have to port the patches for the prompt buffer. @erw ported some of them in https://github.com/neovim/neovim/pull/10433 but there's a lot more to resolve.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z',
#   'org': {'id': 6471485,
#    'login': 'neovim',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/neovim',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6471485?'}},
#  {'id': '13710755946',
#   'type': 'DeleteEvent',
#   'actor': {'id': 343057,
#    'login': 'rdiankov',
#    'display_login': 'rdiankov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rdiankov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/343057?'},
#   'repo': {'id': 5805151,
#    'name': 'rdiankov/openrave',
#    'url': 'https://api.github.com/repos/rdiankov/openrave'},
#   'payload': {'ref': 'fix_sampler',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755947',
#   'type': 'PushEvent',
#   'actor': {'id': 70292612,
#    'login': 't-dunn',
#    'display_login': 't-dunn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/t-dunn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70292612?'},
#   'repo': {'id': 290599331,
#    'name': 'syoungstone/KidsToDoApp',
#    'url': 'https://api.github.com/repos/syoungstone/KidsToDoApp'},
#   'payload': {'push_id': 5785686312,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/branch_tyler',
#    'head': 'df59b98b52a880a958ec24a54ca56e7ff1efe334',
#    'before': '0b42ac5f2caec9233292305ca278f8bea41fc09f',
#    'commits': [{'sha': 'df59b98b52a880a958ec24a54ca56e7ff1efe334',
#      'author': {'email': 'dunnt5@mymail.vcu.edu', 'name': 'Tyler'},
#      'message': 'Closes phone dialog if auto timed out',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/syoungstone/KidsToDoApp/commits/df59b98b52a880a958ec24a54ca56e7ff1efe334'}]},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755945',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 191633992,
#    'name': 's4heid/branch-switcher',
#    'url': 'https://api.github.com/repos/s4heid/branch-switcher'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/types/jest-26.0.14',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'a GitHub bot that switches the base branch of pull requests to the preferred branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755943',
#   'type': 'PushEvent',
#   'actor': {'id': 8632309,
#    'login': 'ArchanPatel890',
#    'display_login': 'ArchanPatel890',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ArchanPatel890',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8632309?'},
#   'repo': {'id': 280557712,
#    'name': 'ArchanPatel890/CompetitiveProgramming',
#    'url': 'https://api.github.com/repos/ArchanPatel890/CompetitiveProgramming'},
#   'payload': {'push_id': 5785686303,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd498c389bd718f890d5478e2b6d1d682412f3829',
#    'before': '2e102cfccd07e87efcf255b2b1f5fbeef747bb5b',
#    'commits': [{'sha': 'd498c389bd718f890d5478e2b6d1d682412f3829',
#      'author': {'email': 'archan.patel890@gmail.com',
#       'name': 'ArchanPatel890'},
#      'message': 'Added Official Contest GraknForces 2020. Added Practice Round 655 (div 2). Modified template.h to include additional typedefs.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ArchanPatel890/CompetitiveProgramming/commits/d498c389bd718f890d5478e2b6d1d682412f3829'}]},
#   'public': True,
#   'created_at': '2020-10-02T02:08:10Z'},
#  {'id': '13710755944',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 30537854,
#    'login': 'signcla-test-signed-corp',
#    'display_login': 'signcla-test-signed-corp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/signcla-test-signed-corp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30537854?'},
#   'repo': {'id': 98467418,
#    'name': 'google-test/signcla-probe-repo',
#    'url': 'https://api.github.com/repos/google-test/signcla-probe-repo'},
#   'payload': {'action': 'closed',
#    'number': 348027,
#    'pull_request': {'url': 'https://api.github.com/repos/google-test/signcla-probe-repo/pulls/348027',
#     'id': 496639291,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDk2NjM5Mjkx',
#     'html_url': 'https://github.com/google-test/signcla-probe-repo/pull/348027',
#     'diff_url': 'https://github.com/google-test/signcla-probe-repo/pull/348027.diff',
#     'patch_url': 'https://github.com/google-test/signcla-probe-repo/pull/348027.patch',
#     'issue_url': 'https://api.github.com/repos/google-test/signcla-probe-repo/issues/348027',
#     'number': 348027,
#     'state': 'closed',
#     'locked': False,
#     'title': 'New PR to test SignCLA at 2020-10-01 19:07:42.75575278 -0700 PDT m=+27995.625200144',
#     'user': {'login': 'signcla-test-signed-corp',
#      'id': 30537854,
#      'node_id': 'MDQ6VXNlcjMwNTM3ODU0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/30537854?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/signcla-test-signed-corp',
#      'html_url': 'https://github.com/signcla-test-signed-corp',
#      'followers_url': 'https://api.github.com/users/signcla-test-signed-corp/followers',
#      'following_url': 'https://api.github.com/users/signcla-test-signed-corp/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/signcla-test-signed-corp/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/signcla-test-signed-corp/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/signcla-test-signed-corp/subscriptions',
#      'organizations_url': 'https://api.github.com/users/signcla-test-signed-corp/orgs',
#      'repos_url': 'https://api.github.com/users/signcla-test-signed-corp/repos',
#      'events_url': 'https://api.github.com/users/signcla-test-signed-corp/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/signcla-test-signed-corp/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Body of PR',
#     'created_at': '2020-10-02T02:07:43Z',
#     'updated_at': '2020-10-02T02:08:08Z',
#     'closed_at': '2020-10-02T02:08:08Z',
#     'merged_at': None,
#     'merge_commit_sha': '9566bfee1dfda71d19a70d30033046f3e8994973',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 671832460,
#       'node_id': 'MDU6TGFiZWw2NzE4MzI0NjA=',
#       'url': 'https://api.github.com/repos/google-test/signcla-probe-repo/labels/cla:%20yes',
#       'name': 'cla: yes',
#       'color': '0e8a16',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/google-test/signcla-probe-repo/pulls/348027/commits',
#     'review_comments_url': 'https://api.github.com/repos/google-test/signcla-probe-repo/pulls/348027/comments',
#     'review_comment_url': 'https://api.github.com/repos/google-test/signcla-probe-repo/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/google-test/signcla-probe-repo/issues/348027/comments',
#     'statuses_url': 'https://api.github.com/repos/google-test/signcla-probe-repo/statuses/b3fb91f15501edbc1ef5cf82aee451aeedc38be7',
#     'head': {'label': 'google-test2:signcla-prober-1-f897721a-3aff-4108-89d6-aa7d8a88c7e1-fork',
#      'ref': 'signcla-prober-1-f897721a-3aff-4108-89d6-aa7d8a88c7e1-fork',
#      'sha': 'b3fb91f15501edbc1ef5cf82aee451aeedc38be7',
#      'user': {'login': 'google-test2',
#       'id': 9579519,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk1Nzk1MTk=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/9579519?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/google-test2',
#       'html_url': 'https://github.com/google-test2',
#       'followers_url': 'https://api.github.com/users/google-test2/followers',
#       'following_url': 'https://api.github.com/users/google-test2/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/google-test2/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/google-test2/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/google-test2/subscriptions',
#       'organizations_url': 'https://api.github.com/users/google-test2/orgs',
#       'repos_url': 'https://api.github.com/users/google-test2/repos',
#       'events_url': 'https://api.github.com/users/google-test2/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/google-test2/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 109173371,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDkxNzMzNzE=',
#       'name': 'signcla-probe-repo',
#       'full_name': 'google-test2/signcla-probe-repo',
#       'private': False,
#       'owner': {'login': 'google-test2',
#        'id': 9579519,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk1Nzk1MTk=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/9579519?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/google-test2',
#        'html_url': 'https://github.com/google-test2',
#        'followers_url': 'https://api.github.com/users/google-test2/followers',
#        'following_url': 'https://api.github.com/users/google-test2/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/google-test2/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/google-test2/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/google-test2/subscriptions',
#        'organizations_url': 'https://api.github.com/users/google-test2/orgs',
#        'repos_url': 'https://api.github.com/users/google-test2/repos',
#        'events_url': 'https://api.github.com/users/google-test2/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/google-test2/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/google-test2/signcla-probe-repo',
#       'description': 'Repo used to probe that SignCLA is functioning correctly.  DO NOT REMOVE',
#       'fork': True,
#       'url': 'https://api.github.com/repos/google-test2/signcla-probe-repo',
#       'forks_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/forks',
#       'keys_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/teams',
#       'hooks_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/hooks',
#       'issue_events_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/events',
#       'assignees_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/tags',
#       'blobs_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/languages',
#       'stargazers_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/stargazers',
#       'contributors_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/contributors',
#       'subscribers_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/subscribers',
#       'subscription_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/subscription',
#       'commits_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/merges',
#       'archive_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/downloads',
#       'issues_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/google-test2/signcla-probe-repo/milestones{/number}',
# ...
#     'created_at': '2020-10-02T02:08:09Z',
#     'updated_at': '2020-10-02T02:08:09Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/jhutchings1/vscode/pulls/324/commits',
#     'review_comments_url': 'https://api.github.com/repos/jhutchings1/vscode/pulls/324/comments',
#     'review_comment_url': 'https://api.github.com/repos/jhutchings1/vscode/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/jhutchings1/vscode/issues/324/comments',
#     'statuses_url': 'https://api.github.com/repos/jhutchings1/vscode/statuses/5052a7bc2ec35879b4ef5c835de78c9620bc1d9e',
#     'head': {'label': 'microsoft:master',
#      'ref': 'master',
#      'sha': '5052a7bc2ec35879b4ef5c835de78c9620bc1d9e',
#      'user': {'login': 'microsoft',
#       'id': 6154722,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/6154722?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/microsoft',
#       'html_url': 'https://github.com/microsoft',
#       'followers_url': 'https://api.github.com/users/microsoft/followers',
#       'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#       'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#       'repos_url': 'https://api.github.com/users/microsoft/repos',
#       'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 41881900,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0MTg4MTkwMA==',
#       'name': 'vscode',
#       'full_name': 'microsoft/vscode',
#       'private': False,
#       'owner': {'login': 'microsoft',
#        'id': 6154722,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/6154722?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/microsoft',
#        'html_url': 'https://github.com/microsoft',
#        'followers_url': 'https://api.github.com/users/microsoft/followers',
#        'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#        'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#        'repos_url': 'https://api.github.com/users/microsoft/repos',
#        'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/microsoft/vscode',
#       'description': 'Visual Studio Code',
#       'fork': False,
#       'url': 'https://api.github.com/repos/microsoft/vscode',
#       'forks_url': 'https://api.github.com/repos/microsoft/vscode/forks',
#       'keys_url': 'https://api.github.com/repos/microsoft/vscode/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/microsoft/vscode/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/microsoft/vscode/teams',
#       'hooks_url': 'https://api.github.com/repos/microsoft/vscode/hooks',
#       'issue_events_url': 'https://api.github.com/repos/microsoft/vscode/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/microsoft/vscode/events',
#       'assignees_url': 'https://api.github.com/repos/microsoft/vscode/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/microsoft/vscode/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/microsoft/vscode/tags',
#       'blobs_url': 'https://api.github.com/repos/microsoft/vscode/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/microsoft/vscode/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/microsoft/vscode/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/microsoft/vscode/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/microsoft/vscode/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/microsoft/vscode/languages',
#       'stargazers_url': 'https://api.github.com/repos/microsoft/vscode/stargazers',
#       'contributors_url': 'https://api.github.com/repos/microsoft/vscode/contributors',
#       'subscribers_url': 'https://api.github.com/repos/microsoft/vscode/subscribers',
#       'subscription_url': 'https://api.github.com/repos/microsoft/vscode/subscription',
#       'commits_url': 'https://api.github.com/repos/microsoft/vscode/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/microsoft/vscode/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/microsoft/vscode/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/microsoft/vscode/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/microsoft/vscode/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/microsoft/vscode/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/microsoft/vscode/merges',
#       'archive_url': 'https://api.github.com/repos/microsoft/vscode/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/microsoft/vscode/downloads',
#       'issues_url': 'https://api.github.com/repos/microsoft/vscode/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/microsoft/vscode/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/microsoft/vscode/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/microsoft/vscode/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/microsoft/vscode/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/microsoft/vscode/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/microsoft/vscode/deployments',
#       'created_at': '2015-09-03T20:23:38Z',
#       'updated_at': '2020-10-02T00:34:59Z',
#       'pushed_at': '2020-10-02T01:22:08Z',
#       'git_url': 'git://github.com/microsoft/vscode.git',
#       'ssh_url': 'git@github.com:microsoft/vscode.git',
#       'clone_url': 'https://github.com/microsoft/vscode.git',
#       'svn_url': 'https://github.com/microsoft/vscode',
#       'homepage': 'https://code.visualstudio.com',
#       'size': 307725,
#       'stargazers_count': 104001,
#       'watchers_count': 104001,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 16543,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5628,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 16543,
#       'open_issues': 5628,
#       'watchers': 104001,
#       'default_branch': 'master'}},
#     'base': {'label': 'jhutchings1:master',
#      'ref': 'master',
#      'sha': 'bdddde3da2fbf5a05cdc8d0fe3b1b76f4f8ed9c4',
#      'user': {'login': 'jhutchings1',
#       'id': 12853539,
#       'node_id': 'MDQ6VXNlcjEyODUzNTM5',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/12853539?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jhutchings1',
#       'html_url': 'https://github.com/jhutchings1',
#       'followers_url': 'https://api.github.com/users/jhutchings1/followers',
#       'following_url': 'https://api.github.com/users/jhutchings1/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jhutchings1/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jhutchings1/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jhutchings1/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jhutchings1/orgs',
#       'repos_url': 'https://api.github.com/users/jhutchings1/repos',
#       'events_url': 'https://api.github.com/users/jhutchings1/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jhutchings1/received_events',
#       'type': 'User',
#       'site_admin': True},
#      'repo': {'id': 278993021,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzg5OTMwMjE=',
#       'name': 'vscode',
#       'full_name': 'jhutchings1/vscode',
#       'private': False,
#       'owner': {'login': 'jhutchings1',
#        'id': 12853539,
#        'node_id': 'MDQ6VXNlcjEyODUzNTM5',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/12853539?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jhutchings1',
#        'html_url': 'https://github.com/jhutchings1',
#        'followers_url': 'https://api.github.com/users/jhutchings1/followers',
#        'following_url': 'https://api.github.com/users/jhutchings1/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jhutchings1/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jhutchings1/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jhutchings1/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jhutchings1/orgs',
#        'repos_url': 'https://api.github.com/users/jhutchings1/repos',
#        'events_url': 'https://api.github.com/users/jhutchings1/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jhutchings1/received_events',
#        'type': 'User',
#        'site_admin': True},
#       'html_url': 'https://github.com/jhutchings1/vscode',
#       'description': 'Visual Studio Code',
#       'fork': True,
#       'url': 'https://api.github.com/repos/jhutchings1/vscode',
#       'forks_url': 'https://api.github.com/repos/jhutchings1/vscode/forks',
#       'keys_url': 'https://api.github.com/repos/jhutchings1/vscode/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jhutchings1/vscode/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jhutchings1/vscode/teams',
#       'hooks_url': 'https://api.github.com/repos/jhutchings1/vscode/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jhutchings1/vscode/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jhutchings1/vscode/events',
#       'assignees_url': 'https://api.github.com/repos/jhutchings1/vscode/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jhutchings1/vscode/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jhutchings1/vscode/tags',
#       'blobs_url': 'https://api.github.com/repos/jhutchings1/vscode/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jhutchings1/vscode/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jhutchings1/vscode/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jhutchings1/vscode/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jhutchings1/vscode/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jhutchings1/vscode/languages',
#       'stargazers_url': 'https://api.github.com/repos/jhutchings1/vscode/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jhutchings1/vscode/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jhutchings1/vscode/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jhutchings1/vscode/subscription',
#       'commits_url': 'https://api.github.com/repos/jhutchings1/vscode/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jhutchings1/vscode/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jhutchings1/vscode/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jhutchings1/vscode/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jhutchings1/vscode/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jhutchings1/vscode/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jhutchings1/vscode/merges',
#       'archive_url': 'https://api.github.com/repos/jhutchings1/vscode/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jhutchings1/vscode/downloads',
#       'issues_url': 'https://api.github.com/repos/jhutchings1/vscode/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jhutchings1/vscode/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jhutchings1/vscode/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jhutchings1/vscode/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jhutchings1/vscode/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jhutchings1/vscode/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jhutchings1/vscode/deployments',
#       'created_at': '2020-07-12T04:46:58Z',
#       'updated_at': '2020-10-01T20:08:08Z',
#       'pushed_at': '2020-10-01T20:08:05Z',
#       'git_url': 'git://github.com/jhutchings1/vscode.git',
#       'ssh_url': 'git@github.com:jhutchings1/vscode.git',
#       'clone_url': 'https://github.com/jhutchings1/vscode.git',
#       'svn_url': 'https://github.com/jhutchings1/vscode',
#       'homepage': 'https://code.visualstudio.com',
#       'size': 307129,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jhutchings1/vscode/pulls/324'},
#      'html': {'href': 'https://github.com/jhutchings1/vscode/pull/324'},
#      'issue': {'href': 'https://api.github.com/repos/jhutchings1/vscode/issues/324'},
#      'comments': {'href': 'https://api.github.com/repos/jhutchings1/vscode/issues/324/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jhutchings1/vscode/pulls/324/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jhutchings1/vscode/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jhutchings1/vscode/pulls/324/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jhutchings1/vscode/statuses/5052a7bc2ec35879b4ef5c835de78c9620bc1d9e'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 2,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-10-02T02:08:09Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f768cb7-1c801d40296f49500008a029'},
#  'origin': '140.114.77.11',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f768cb7-476f9b272b0774d635c201a1'},
#  'json': None,
#  'origin': '140.114.77.11',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f768cb8-394e565c428155005a9e026b'},
#  'json': None,
#  'origin': '140.114.77.11',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post')
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f768d3e-4991e1c27a8df7d62ec25713'},
#  'json': None,
#  'origin': '140.114.77.11',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.post('http://httpbin.org/post', data = "send you some message")
json.loads(r.text)
# Out:
# {'args': {},
#  'data': 'send you some message',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '21',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f768d29-645656b31e5bcd26655527dd'},
#  'json': None,
#  'origin': '140.114.77.11',
#  'url': 'http://httpbin.org/post'}
