# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html")
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# <a class="right small" href="/about.html">關於我們</a>
# ...

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
soup.find_all('a')

for d in soup.find_all(class_="title"):
    #print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html")
        info = r.find_all(class_='article-meta-value')
        print("Author: %s \t Title:%s \t Time:%s"%(info[0].text, info[2].text, info[3].text) )        
    except:
        continue
# Out:
# Author: reminiscence (記憶回溯) 	 Title:Re: [花邊] 志傑技巧比我豪強？ 	 Time:Thu Oct 29 12:49:17 2020
# Author: liusim (六四母) 	 Title:Re: [花邊] 快艇隊祝賀同城道奇隊奪得世界大賽冠軍 	 Time:Thu Oct 29 12:56:02 2020
# Author: ericf129 (☆小艾克★) 	 Title:[新聞] 喬丹女婿赴台隔離訓練 動態暗示計畫挑戰S 	 Time:Thu Oct 29 13:56:16 2020
# Author: lai162 (I AM THE GATE) 	 Title:[花邊] LBJ轉發Betts推特:沒人滿足於1個,2個,3個 	 Time:Thu Oct 29 14:10:27 2020
# Author: thnlkj0665 (灰色地帶) 	 Title:[花邊] 投身自由市場 Gallinari:不見得會去爭冠球隊 	 Time:Thu Oct 29 14:12:29 2020
# Author: jk182325 (萬里花我老婆) 	 Title:[花邊] 球迷目擊「林書豪與K湯一起訓練」　豪哥 	 Time:Thu Oct 29 15:04:15 2020
# Author: Vedan (味丹) 	 Title:[公告] 第一次被退文，可在三天後刪除退文 	 Time:Mon Mar  9 11:44:26 2020
# Author: Acetoxy (阿斯) 	 Title:[情報] Playoffs Schedule 19–20 	 Time:Tue Aug 18 04:10:40 2020
# Author: namie810303 (爽喔!! 你看看你) 	 Title:[公告] 季後賽條款於10/14零時解除 	 Time:Tue Oct 13 22:39:02 2020

# %%
for info in r.find_all(class_='article-meta-value'):
    print(info.text)
# Out:
# namie810303 (爽喔!! 你看看你)
# NBA
# [公告] 季後賽條款於10/14零時解除
# Tue Oct 13 22:39:02 2020

# %%
r
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>[公告] 季後賽條款於10/14零時解除 - 看板 NBA - 批踢踢實業坊</title>
# <meta content="all" name="robots"/>
# <meta content="Ptt BBS 批踢踢" name="keywords"/>
# <meta content="過往總冠軍戰結束後
# 版上仍會熱鬧個三天
# 因此不會馬上解除
# 所以到10/14之前的版上相關規定
# 都是按照季後賽條款處理
# " name="description"/>
# <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
# <meta content="[公告] 季後賽條款於10/14零時解除" property="og:title"/>
# <meta content="過往總冠軍戰結束後
# 版上仍會熱鬧個三天
# 因此不會馬上解除
# 所以到10/14之前的版上相關規定
# 都是按照季後賽條款處理
# " property="og:description"/>
# <link href="https://www.ptt.cc/bbs/NBA/M.1602599945.A.C45.html" rel="canonical"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
